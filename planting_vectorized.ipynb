# %% [markdown]
# ## Planting Model
# #### Madison Mina
# Trying to determine plant relationships through similarity of features from multiple datasets. This will help to plan which plants live best together in the 5 time rotating Show Dome.
#
# **Datasets:**
# - companion_plants.csv: no
# > all vegetables, but there is relation category (could be helpful)
# - DATA FOR Functional Ecology: no
# > contains measured traits of tropical tree species from French Guiana
# - GlobResp database_Atkin: yes
# > global leaf respiration database,It measures how leaves breathe (respire), how they handle temperature, etc. KNOW THAT: Plant name = species
# - morphology.csv: yes
# > Morphological traits describe the shape, structure, and physical form of plants.
# - physiology.csv: yes
# > Physiological traits metabolic, biochemical, and gas>exchange processes.
# - transpiration.csv: yes
# > water loss, water usage, drought tolerance, and stomatal behavior — the key drivers of plant survival in different climates
# - TRY: yes
# > The TRY database merges hundreds of datasets contributed by different labs worldwide. These categorical traits massively help compatibility clustering

# %%
import pandas as pd 

glob_leaf_df = pd.read_csv("datasets/GlobResp database_Atkin et al 2015_New Phytologist.csv")

glob_leaf_df.head(50)
# Out:
#         Country    Biome             Site  Latitude  Longitude  Altitude  \
# 0    Costa Rica  TrRF_lw  10?26'N_83?59'W   10.4300   -83.9800       105
# 1    Costa Rica  TrRF_lw  10?28'N_84?02'W   10.4700   -84.0300       140
# 2    Bangladesh  TrRF_lw   24?12'N_90?9'E   24.2000    90.1500        21
# 3        USA-PN     TeDF  40?47'N_77?53'W   40.7800   -77.8800       348
# 4        USA-PN     TeDF  40?48'N_77?50'W   40.8000   -77.8300       335
# 5        USA-PN     TeDF  40?48'N_77?50'W   40.8000   -77.8300       335
# 6        USA-PN     TeDF  40?49'N_77?56'W   40.8200   -77.9300       400
# 7     Venezuela  TrRF_lw  8?39'N__71?24'W    8.6500   -71.4000      2350
# 8        Panama  TrRF_lw  9?10'N__79?51'W    9.1700   -79.8500        90
# 9        USA-MI     TeDF          Allegan   42.5300   -85.8550       200
# 10  Peru-Amazon  TrRF_lw           ALP-01   -3.9491   -73.4346       120
# 11  Peru-Amazon  TrRF_lw           ALP-01   -3.9491   -73.4346       120
# ...
